# %%
import pandas as pd

# %%
import numpy as np

# %%
mba = pd.read_csv("C:\\Users\\Rohit\\Desktop\\PPTS\\mba.csv")

# %%
mba
# Out:
#      Datasrno  workex  gmat
# 0           1      21   720
# 1           2     107   640
# 2           3      57   740
# 3           4      99   690
# 4           5     208   710
# 5           6     136   660
# 6           7      70   660
# 7           8     103   710
# 8           9      79   700
# 9          10      22   730
# 10         11      69   700
# 11         12      41   740
# 12         13      72   650
# 13         14      69   720
# 14         15      20   700
# 15         16      21   760
# 16         17      19   710
# 17         18      86   720
# 18         19     231   690
# 19         20      20   770
# 20         21     175   660
# 21         22      21   710
# 22         23      44   720
# 23         24      23   650
# 24         25      20   710
# 25         26      70   720
# 26         27      46   710
# 27         28      33   650
# 28         29     130   690
# 29         30      57   690
# ..        ...     ...   ...
# 743       744      94   740
# ...

# %%
mba
# number of Rows
len(mba)
# Out:
# 773

# %%
# check the number of columns 
len(mba.columns)
# Out:
# 3

# %%
mba.shape
# Out:
# (773, 3)

# %%
# column Names
mba.columns
# Out:
# Index(['Datasrno', 'workex', 'gmat'], dtype='object')

# %%
# Top rows
mba.head(20) # will give top 5 rows
# Out:
#     Datasrno  workex  gmat
# 0          1      21   720
# 1          2     107   640
# 2          3      57   740
# 3          4      99   690
# 4          5     208   710
# 5          6     136   660
# 6          7      70   660
# 7          8     103   710
# 8          9      79   700
# 9         10      22   730
# 10        11      69   700
# 11        12      41   740
# 12        13      72   650
# 13        14      69   720
# 14        15      20   700
# 15        16      21   760
# 16        17      19   710
# 17        18      86   720
# 18        19     231   690
# 19        20      20   770

# %%
# mention number of rows to display
mba.head(6)
# Out:
#    Datasrno  workex  gmat
# 0         1      21   720
# 1         2     107   640
# 2         3      57   740
# 3         4      99   690
# 4         5     208   710
# 5         6     136   660

# %%
# tail function to bottom rows
mba.tail(6)
# Out:
#      Datasrno  workex  gmat
# 767       768      38   680
# 768       769      88   620
# 769       770     132   670
# 770       771      28   610
# 771       772      10   610
# 772       773      52   620

# %%
# column information dataset structure
mba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 773 entries, 0 to 772
# Data columns (total 3 columns):
# Datasrno    773 non-null int64
# workex      773 non-null int64
# gmat        773 non-null int64
# dtypes: int64(3)
# memory usage: 18.2 KB

# %%
# Get stats  on the columns
mba.describe()
# Out:
#         Datasrno     workex        gmat
# count  773.00000  773.00000  773.000000
# mean   387.00000   57.50194  711.164295
# std    223.29017   27.38682   29.339714
# min      1.00000    9.00000  600.000000
# 25%    194.00000   41.00000  690.000000
# 50%    387.00000   52.00000  710.000000
# 75%    580.00000   69.00000  730.000000
# max    773.00000  279.00000  780.000000

# %%
mba.describe().transpose()
# Out:
#           count        mean         std    min    25%    50%    75%    max
# Datasrno  773.0  387.000000  223.290170    1.0  194.0  387.0  580.0  773.0
# workex    773.0   57.501940   27.386820    9.0   41.0   52.0   69.0  279.0
# gmat      773.0  711.164295   29.339714  600.0  690.0  710.0  730.0  780.0

# %%
# Rows information
mba[23:27]
# Out:
#     Datasrno  workex  gmat
# 23        24      23   650
# 24        25      20   710
# 25        26      70   720
# 26        27      46   710

# %%
mba['workex']
# Out:
# 0       21
# 1      107
# 2       57
# 3       99
# 4      208
# 5      136
# 6       70
# 7      103
# 8       79
# 9       22
# 10      69
# 11      41
# 12      72
# 13      69
# 14      20
# 15      21
# 16      19
# 17      86
# 18     231
# 19      20
# 20     175
# 21      21
# 22      44
# 23      23
# 24      20
# 25      70
# 26      46
# 27      33
# 28     130
# 29      57
#       ...
# 743     94
# 744    105
# 745     95
# 746     43
# 747     89
# 748     68
# 749     46
# 750     69
# 751     93
# 752     60
# 753     69
# 754     68
# 755     46
# 756     23
# 757     50
# 758     33
# 759     39
# 760     34
# 761     69
# 762     34
# 763     31
# 764     29
# 765     46
# 766     44
# 767     38
# 768     88
# 769    132
# 770     28
# 771     10
# 772     52
# Name: workex, Length: 773, dtype: int64

# %%
mba1 = mba[['workex','gmat']]

# %%
mba1
# Out:
#      workex  gmat
# 0        21   720
# 1       107   640
# 2        57   740
# 3        99   690
# 4       208   710
# 5       136   660
# 6        70   660
# 7       103   710
# 8        79   700
# 9        22   730
# 10       69   700
# 11       41   740
# 12       72   650
# 13       69   720
# 14       20   700
# 15       21   760
# 16       19   710
# 17       86   720
# 18      231   690
# 19       20   770
# 20      175   660
# 21       21   710
# 22       44   720
# 23       23   650
# 24       20   710
# 25       70   720
# 26       46   710
# 27       33   650
# 28      130   690
# 29       57   690
# ..      ...   ...
# 743      94   740
# 744     105   710
# 745      95   710
# 746      43   720
# 747      89   710
# 748      68   730
# 749      46   750
# 750      69   740
# 751      93   710
# 752      60   680
# 753      69   740
# 754      68   740
# 755      46   730
# 756      23   770
# 757      50   720
# 758      33   680
# 759      39   680
# 760      34   740
# ...

# %%
mba.mean()
# Out:
# Datasrno    387.000000
# workex       57.501940
# gmat        711.164295
# dtype: float64

# %%
mba.std()
# Out:
# Datasrno    223.290170
# workex       27.386820
# gmat         29.339714
# dtype: float64

# %%
mba.describe()
# Out:
#         Datasrno     workex        gmat
# count  773.00000  773.00000  773.000000
# mean   387.00000   57.50194  711.164295
# std    223.29017   27.38682   29.339714
# min      1.00000    9.00000  600.000000
# 25%    194.00000   41.00000  690.000000
# 50%    387.00000   52.00000  710.000000
# 75%    580.00000   69.00000  730.000000
# max    773.00000  279.00000  780.000000

# %%
mba['gmat'].mean()
# Out:
# 711.1642949547219

# %%
mba['gmat'].median()
# Out:
# 710.0

# %%
mba['gmat'].mode()
# Out:
# 0    710
# dtype: int64

# %%
mba['gmat'].var()
# Out:
# 860.8188271253223

# %%
mba['gmat'].std()
# Out:
# 29.33971416229753

# %%
max(mba['gmat'])
# Out:
# 780

# %%
min(mba['gmat'])
# Out:
# 600

# %%
range = max(mba['gmat'])-min(mba['gmat'])
range
# Out:
# 180

# %%
from scipy.stats import skew

skew(mba['gmat'])
# Out:
# -0.594320384238288

# %%
from scipy.stats import kurtosis
kurtosis(mba['gmat'])
# Out:
# 1.1518763065845246
